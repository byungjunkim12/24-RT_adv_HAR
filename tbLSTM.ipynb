# %%
import numpy as np
import scipy.io as sio
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import linalg as LA

import csv
import os
import json
import math
import time
import pickle

from glob import glob
from collections import defaultdict
from scipy import signal
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import matplotlib.pyplot as plt

from utilities import *
from utilitiesDL import *

# %% [markdown]
# ## Parameter Configuration

# %%
jsonFileName = './inputJson/genData.json'

f = open(jsonFileName)
inputJson = json.load(f)
dataPathBase = inputJson['dataPathBase']
dataType = inputJson['dataType']
cudaID = 5
f.close()

print("Datatype:", dataType)
if dataType == 'survey':
    fs = 1000 # 1 kHz
    nSubC = 30
    nRX = 3
    
    dSampFactor = 10
    activities = ['bed', 'fall', 'run', 'sitdown', 'standup', 'walk']
    # activities = ['fall', 'pickup', 'run', 'sitdown', 'standup', 'walk']

torch.set_num_threads(1)
if cudaID >= 0:
    device = torch.device("cuda:"+str(cudaID))
    cudaAvbl = True
else:
    device = torch.device("cpu")
    cudaAvbl = False

padLen = 9
if dataType == "survey":
    dataPath = dataPathBase + "HAR_survey/"
dataDict = {activity:[] for activity in activities}
for activity in activities:
    dataDict[activity] = defaultdict(list)
dataPath = dataPath + "noWin_dSamp_" + str(dSampFactor) + "_pad_" + str(padLen) + "/"
print('dataPath:', dataPath)
# Out:
# Datatype: survey
# dataPath: /project/iarpa/wifiHAR/HAR_survey/noWin_dSamp_10_pad_9/

# %%
dataDict = {file:[] for file in activities}
lenList = []
ampList = []
for actInd, activity in enumerate(activities):
    longestLen = 0
    shortestLen = 10000

    dataDict[activity] = defaultdict(list)

    xxLoadNP = np.load(dataPath + "xx_" + activity + ".npy", allow_pickle=True)
    # if xxLoadNP.shape[0] > longestLen:
    #     longestLen = xxLoadNP.shape[0]
    for dataInd, data in enumerate(xxLoadNP):
        if data.shape[0] > longestLen:
            longestLen = data.shape[0]
        if data.shape[0] < shortestLen:
            shortestLen = data.shape[0]
        # if data.shape[0] < lenThres:
        dataDict[activity]['input'].append(data)
        ampList.append(LA.norm(torch.Tensor(data)))
        # data = torch.Tensor(data) / LA.norm(torch.Tensor(data)) * torch.numel(torch.Tensor(data))
        lenList.append(LA.norm(torch.Tensor(data)))
        
        dataDict[activity]['label'] = actInd*torch.ones(len(dataDict[activity]['input']), dtype=int, device=device)
    print(activity, len(dataDict[activity]['input']), len(dataDict[activity]['label']), shortestLen, longestLen)
# plt.hist(lenList, bins=20)
# plt.hist(ampList, bins=20)
# Out:
# /home/byk004/miniconda3/envs/wifiHAR_vel/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# bed 79 79 201 491
# fall 79 79 166 339
# run 80 80 339 1140
# sitdown 80 80 134 353
# standup 79 79 115 332
# walk 80 80 553 1010

# %% [markdown]
# ## Create training, test torch dataset

# %%
batchSize = 1

trData = list()
tsData = list()
for activity in activities:
    dataset = CSIDataset(dataDict[activity], device,\
                        normalize=True,\
                        nSubC=nSubC,\
                        nRX=nRX,\
                        padLen=padLen)
    nTrData = np.floor(len(dataset)*0.8).astype(int)
    nTsData = np.floor(len(dataset)*0.2).astype(int)
    trData.append(torch.utils.data.Subset(dataset, range(nTrData)))
    tsData.append(torch.utils.data.Subset(dataset, range(nTrData, nTrData+nTsData)))
    print(activity, nTrData, nTsData, len(dataset))

trDataset = torch.utils.data.ConcatDataset(trData) # concatenating dataset lists
tsDataset = torch.utils.data.ConcatDataset(tsData)

trLoader = DataLoader(trDataset, batch_size=batchSize, shuffle=True, collate_fn=collate_fn)
tsLoader = DataLoader(tsDataset, batch_size=batchSize, shuffle=True, collate_fn=collate_fn)
print("# of tr data:", len(trDataset), "# of ts data:", len(tsDataset))
# Out:
# bed 63 15 79
# fall 63 15 79
# run 64 16 80
# sitdown 64 16 80
# standup 63 15 79
# walk 64 16 80
# # of tr data: 381 # of ts data: 93

# %%
LSTMLoss = torch.nn.CrossEntropyLoss()
nHidden = 200
LR = 2e-5
maxPatience = 30
nEpoch = 200
bidirectional = True
if bidirectional:
    modelName = 'BiLSTM'
else:
    modelName = 'LSTM'

modelFileName = dataType + "_" + modelName + "_H_" + str(nHidden) + "_dS_" + str(dSampFactor) + ".cpkt"
HARNetSavePath = './savedModels/LSTM/' + modelFileName
print('save model path:', HARNetSavePath)
fromInit = False

HARNet = VariableLSTMNet(nClasses=len(activities),\
                input_size=nSubC*nRX,\
                bidirectional=bidirectional,\
                hidden_size=nHidden,\
                num_layers=1,\
                device=device)
HARNet.to(device)

if fromInit:
    HARNet.apply(init_weights)
else:
    HARNet.load_state_dict(torch.load(HARNetSavePath))
opt = torch.optim.Adam(HARNet.parameters(), lr=LR)
# Out:
# save model path: ./savedModels/LSTM/survey_BiLSTM_H_200_dS_10.cpkt

# %%
bestAcc = 0.0
patience = 0
fastConvg = True

torch.set_num_threads(1)
print('save model path:', HARNetSavePath)
for epoch in range(nEpoch):
    runningLoss = 0.0
    HARNet.train()      
    for trInput, trLabel in trLoader:
        trLabel = trLabel.to(device)
        # print(trLabel)
        opt.zero_grad()
        
        trOutput = HARNet(trInput)
        # print(trOutput.shape)
        trloss = LSTMLoss(trOutput, trLabel)
        trloss.backward()
        opt.step()
        runningLoss += trloss.item()

    avgTrLoss = runningLoss / len(trLoader)
    accTrain = getAcc(trLoader, padLen, HARNet, variableLen=True)

    runningLoss = 0.0
    for tsInput, tsLabel in tsLoader:
        tsLabel = tsLabel.to(device)
        opt.zero_grad()
        # tsInput = tsData['input']
        # tsLabel = tsData['label']
        
        tsOutput = HARNet(tsInput)
        tsloss = LSTMLoss(tsOutput, tsLabel)
        runningLoss += tsloss.item()

    avgTsLoss = runningLoss / len(tsLoader)
    accTest = getAcc(tsLoader, padLen, HARNet, variableLen=True)

    print('Epoch: %d, trLoss: %.3f, trAcc: %.3f, tsLoss: %.3f, tsAcc: %.3f'\
        % (epoch, avgTrLoss, accTrain, avgTsLoss, accTest))
    if bestAcc < accTest:
        bestAcc = accTest
        print('saving model')
        torch.save(HARNet.state_dict(), HARNetSavePath)  # saving model with best test accuracy
        patience = 0

    # print(trData.shape, trLabel.shape)
    # early stopping if model converges twice
    patience += 1
    if patience > maxPatience:
        if fastConvg:
            LR = LR/10
            opt = torch.optim.Adam(HARNet.parameters(), lr=LR)
            patience = 0
            fastConvg = False
            print('fast convergence ends')
        else:
            break

print('Training finished')
# Out:
# save model path: ./savedModels/LSTM/survey_BiLSTM_H_200_dS_10.cpkt
# /home/byk004/24-RT_adv_HAR/utilities.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   label = torch.tensor(self.labels[idx], device=self.device).long()
# /home/byk004/24-RT_adv_HAR/utilities.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inputs_padded = pad_sequence([torch.tensor(seq) for seq in inputs],
# Epoch: 0, trLoss: 1.215, trAcc: 0.835, tsLoss: 1.305, tsAcc: 0.774
# saving model
# Epoch: 1, trLoss: 1.239, trAcc: 0.903, tsLoss: 1.249, tsAcc: 0.849
# saving model
# Epoch: 2, trLoss: 1.217, trAcc: 0.916, tsLoss: 1.233, tsAcc: 0.839
# Epoch: 3, trLoss: 1.200, trAcc: 0.898, tsLoss: 1.222, tsAcc: 0.860
# saving model
# Epoch: 4, trLoss: 1.182, trAcc: 0.913, tsLoss: 1.225, tsAcc: 0.839
# Epoch: 5, trLoss: 1.189, trAcc: 0.903, tsLoss: 1.239, tsAcc: 0.871
# saving model
# Epoch: 6, trLoss: 1.226, trAcc: 0.843, tsLoss: 1.271, tsAcc: 0.796
# Epoch: 7, trLoss: 1.180, trAcc: 0.913, tsLoss: 1.212, tsAcc: 0.839
# Epoch: 8, trLoss: 1.161, trAcc: 0.921, tsLoss: 1.217, tsAcc: 0.839
# Epoch: 9, trLoss: 1.241, trAcc: 0.858, tsLoss: 1.259, tsAcc: 0.828
# Epoch: 10, trLoss: 1.212, trAcc: 0.840, tsLoss: 1.267, tsAcc: 0.796
# Epoch: 11, trLoss: 1.187, trAcc: 0.919, tsLoss: 1.201, tsAcc: 0.871
# Epoch: 12, trLoss: 1.163, trAcc: 0.932, tsLoss: 1.194, tsAcc: 0.882
# saving model
# Epoch: 13, trLoss: 1.159, trAcc: 0.942, tsLoss: 1.193, tsAcc: 0.882
# Epoch: 14, trLoss: 1.141, trAcc: 0.929, tsLoss: 1.200, tsAcc: 0.860
# Epoch: 15, trLoss: 1.154, trAcc: 0.934, tsLoss: 1.213, tsAcc: 0.849
# Epoch: 16, trLoss: 1.135, trAcc: 0.950, tsLoss: 1.191, tsAcc: 0.882
# Epoch: 17, trLoss: 1.150, trAcc: 0.945, tsLoss: 1.194, tsAcc: 0.871
# Epoch: 18, trLoss: 1.139, trAcc: 0.934, tsLoss: 1.193, tsAcc: 0.871
# Epoch: 19, trLoss: 1.144, trAcc: 0.948, tsLoss: 1.202, tsAcc: 0.860
# Epoch: 20, trLoss: 1.166, trAcc: 0.769, tsLoss: 1.297, tsAcc: 0.742
# Epoch: 21, trLoss: 1.214, trAcc: 0.908, tsLoss: 1.219, tsAcc: 0.828
# Epoch: 22, trLoss: 1.173, trAcc: 0.929, tsLoss: 1.219, tsAcc: 0.871
# Epoch: 23, trLoss: 1.189, trAcc: 0.882, tsLoss: 1.267, tsAcc: 0.774
# Epoch: 24, trLoss: 1.164, trAcc: 0.890, tsLoss: 1.218, tsAcc: 0.849
# Epoch: 25, trLoss: 1.163, trAcc: 0.932, tsLoss: 1.228, tsAcc: 0.828
# Epoch: 26, trLoss: 1.159, trAcc: 0.940, tsLoss: 1.203, tsAcc: 0.882
# Epoch: 27, trLoss: 1.150, trAcc: 0.945, tsLoss: 1.204, tsAcc: 0.871
# Epoch: 28, trLoss: 1.138, trAcc: 0.948, tsLoss: 1.177, tsAcc: 0.903
# saving model
# Epoch: 29, trLoss: 1.129, trAcc: 0.963, tsLoss: 1.176, tsAcc: 0.903
# Epoch: 30, trLoss: 1.143, trAcc: 0.790, tsLoss: 1.306, tsAcc: 0.742
# Epoch: 31, trLoss: 1.216, trAcc: 0.929, tsLoss: 1.222, tsAcc: 0.849
# Epoch: 32, trLoss: 1.164, trAcc: 0.940, tsLoss: 1.204, tsAcc: 0.871
# Epoch: 33, trLoss: 1.145, trAcc: 0.955, tsLoss: 1.185, tsAcc: 0.892
# Epoch: 34, trLoss: 1.132, trAcc: 0.961, tsLoss: 1.175, tsAcc: 0.903
# Epoch: 35, trLoss: 1.124, trAcc: 0.942, tsLoss: 1.225, tsAcc: 0.839
# Epoch: 36, trLoss: 1.141, trAcc: 0.955, tsLoss: 1.177, tsAcc: 0.892
# Epoch: 37, trLoss: 1.138, trAcc: 0.840, tsLoss: 1.294, tsAcc: 0.742
# Epoch: 38, trLoss: 1.157, trAcc: 0.948, tsLoss: 1.182, tsAcc: 0.914
# saving model
# Epoch: 39, trLoss: 1.115, trAcc: 0.963, tsLoss: 1.165, tsAcc: 0.903
# Epoch: 40, trLoss: 1.127, trAcc: 0.969, tsLoss: 1.160, tsAcc: 0.914
# Epoch: 41, trLoss: 1.139, trAcc: 0.945, tsLoss: 1.181, tsAcc: 0.882
# Epoch: 42, trLoss: 1.114, trAcc: 0.961, tsLoss: 1.148, tsAcc: 0.925
# saving model
# Epoch: 43, trLoss: 1.108, trAcc: 0.961, tsLoss: 1.159, tsAcc: 0.892
# Epoch: 44, trLoss: 1.103, trAcc: 0.929, tsLoss: 1.179, tsAcc: 0.892
# Epoch: 45, trLoss: 1.277, trAcc: 0.793, tsLoss: 1.330, tsAcc: 0.710
# Epoch: 46, trLoss: 1.267, trAcc: 0.850, tsLoss: 1.326, tsAcc: 0.763
# Epoch: 47, trLoss: 1.205, trAcc: 0.916, tsLoss: 1.241, tsAcc: 0.828
# Epoch: 48, trLoss: 1.147, trAcc: 0.940, tsLoss: 1.208, tsAcc: 0.871
# Epoch: 49, trLoss: 1.214, trAcc: 0.898, tsLoss: 1.276, tsAcc: 0.796
# Epoch: 50, trLoss: 1.159, trAcc: 0.961, tsLoss: 1.191, tsAcc: 0.882
# Epoch: 51, trLoss: 1.131, trAcc: 0.948, tsLoss: 1.177, tsAcc: 0.892
# Epoch: 52, trLoss: 1.136, trAcc: 0.942, tsLoss: 1.204, tsAcc: 0.871
# Epoch: 53, trLoss: 1.138, trAcc: 0.953, tsLoss: 1.204, tsAcc: 0.871
# Epoch: 54, trLoss: 1.123, trAcc: 0.955, tsLoss: 1.172, tsAcc: 0.914
# Epoch: 55, trLoss: 1.120, trAcc: 0.961, tsLoss: 1.155, tsAcc: 0.925
# Epoch: 56, trLoss: 1.104, trAcc: 0.961, tsLoss: 1.164, tsAcc: 0.892
# Epoch: 57, trLoss: 1.126, trAcc: 0.934, tsLoss: 1.212, tsAcc: 0.849
# Epoch: 58, trLoss: 1.132, trAcc: 0.955, tsLoss: 1.181, tsAcc: 0.882
# Epoch: 59, trLoss: 1.120, trAcc: 0.890, tsLoss: 1.217, tsAcc: 0.828
# Epoch: 60, trLoss: 1.150, trAcc: 0.955, tsLoss: 1.194, tsAcc: 0.860
# Epoch: 61, trLoss: 1.153, trAcc: 0.837, tsLoss: 1.266, tsAcc: 0.796
# Epoch: 62, trLoss: 1.142, trAcc: 0.950, tsLoss: 1.188, tsAcc: 0.849
# Epoch: 63, trLoss: 1.112, trAcc: 0.955, tsLoss: 1.180, tsAcc: 0.860
# Epoch: 64, trLoss: 1.103, trAcc: 0.971, tsLoss: 1.144, tsAcc: 0.914
# Epoch: 65, trLoss: 1.095, trAcc: 0.974, tsLoss: 1.147, tsAcc: 0.903
# Epoch: 66, trLoss: 1.105, trAcc: 0.974, tsLoss: 1.161, tsAcc: 0.903
# Epoch: 67, trLoss: 1.096, trAcc: 0.963, tsLoss: 1.157, tsAcc: 0.892
# Epoch: 68, trLoss: 1.102, trAcc: 0.961, tsLoss: 1.154, tsAcc: 0.892
# Epoch: 69, trLoss: 1.097, trAcc: 0.963, tsLoss: 1.172, tsAcc: 0.871
# Epoch: 70, trLoss: 1.097, trAcc: 0.966, tsLoss: 1.162, tsAcc: 0.892
# Epoch: 71, trLoss: 1.094, trAcc: 0.969, tsLoss: 1.161, tsAcc: 0.882
# Epoch: 72, trLoss: 1.154, trAcc: 0.945, tsLoss: 1.163, tsAcc: 0.892
# fast convergence ends
# Epoch: 73, trLoss: 1.108, trAcc: 0.958, tsLoss: 1.149, tsAcc: 0.914
# Epoch: 74, trLoss: 1.094, trAcc: 0.963, tsLoss: 1.148, tsAcc: 0.914
# Epoch: 75, trLoss: 1.092, trAcc: 0.971, tsLoss: 1.147, tsAcc: 0.914
# Epoch: 76, trLoss: 1.088, trAcc: 0.971, tsLoss: 1.146, tsAcc: 0.914
# Epoch: 77, trLoss: 1.087, trAcc: 0.971, tsLoss: 1.146, tsAcc: 0.914
# Epoch: 78, trLoss: 1.086, trAcc: 0.971, tsLoss: 1.140, tsAcc: 0.925
# Epoch: 79, trLoss: 1.085, trAcc: 0.971, tsLoss: 1.139, tsAcc: 0.925
# Epoch: 80, trLoss: 1.084, trAcc: 0.971, tsLoss: 1.139, tsAcc: 0.925
# Epoch: 81, trLoss: 1.084, trAcc: 0.971, tsLoss: 1.138, tsAcc: 0.925
# Epoch: 82, trLoss: 1.085, trAcc: 0.974, tsLoss: 1.136, tsAcc: 0.925
# Epoch: 83, trLoss: 1.082, trAcc: 0.974, tsLoss: 1.137, tsAcc: 0.925
# Epoch: 84, trLoss: 1.082, trAcc: 0.974, tsLoss: 1.136, tsAcc: 0.925
# Epoch: 85, trLoss: 1.081, trAcc: 0.974, tsLoss: 1.135, tsAcc: 0.925
# Epoch: 86, trLoss: 1.081, trAcc: 0.974, tsLoss: 1.134, tsAcc: 0.925
# Epoch: 87, trLoss: 1.080, trAcc: 0.974, tsLoss: 1.137, tsAcc: 0.925
# Epoch: 88, trLoss: 1.080, trAcc: 0.974, tsLoss: 1.135, tsAcc: 0.925
# Epoch: 89, trLoss: 1.080, trAcc: 0.974, tsLoss: 1.137, tsAcc: 0.925
# Epoch: 90, trLoss: 1.081, trAcc: 0.971, tsLoss: 1.135, tsAcc: 0.925
# Epoch: 91, trLoss: 1.080, trAcc: 0.974, tsLoss: 1.132, tsAcc: 0.925
# Epoch: 92, trLoss: 1.078, trAcc: 0.976, tsLoss: 1.127, tsAcc: 0.925
# Epoch: 93, trLoss: 1.077, trAcc: 0.976, tsLoss: 1.126, tsAcc: 0.925
# Epoch: 94, trLoss: 1.081, trAcc: 0.971, tsLoss: 1.132, tsAcc: 0.925
# Epoch: 95, trLoss: 1.080, trAcc: 0.971, tsLoss: 1.130, tsAcc: 0.925
# Epoch: 96, trLoss: 1.080, trAcc: 0.976, tsLoss: 1.128, tsAcc: 0.925
# Epoch: 97, trLoss: 1.075, trAcc: 0.979, tsLoss: 1.120, tsAcc: 0.946
# saving model
# Epoch: 98, trLoss: 1.074, trAcc: 0.976, tsLoss: 1.121, tsAcc: 0.935
# Epoch: 99, trLoss: 1.076, trAcc: 0.979, tsLoss: 1.126, tsAcc: 0.925
# Epoch: 100, trLoss: 1.075, trAcc: 0.979, tsLoss: 1.128, tsAcc: 0.935
# Epoch: 101, trLoss: 1.075, trAcc: 0.979, tsLoss: 1.125, tsAcc: 0.935
# Epoch: 102, trLoss: 1.074, trAcc: 0.979, tsLoss: 1.125, tsAcc: 0.935
# Epoch: 103, trLoss: 1.073, trAcc: 0.979, tsLoss: 1.125, tsAcc: 0.935
# Epoch: 104, trLoss: 1.073, trAcc: 0.979, tsLoss: 1.125, tsAcc: 0.935
# Epoch: 105, trLoss: 1.072, trAcc: 0.979, tsLoss: 1.124, tsAcc: 0.935
# Epoch: 106, trLoss: 1.072, trAcc: 0.979, tsLoss: 1.122, tsAcc: 0.935
# Epoch: 107, trLoss: 1.072, trAcc: 0.979, tsLoss: 1.123, tsAcc: 0.935
# Epoch: 108, trLoss: 1.072, trAcc: 0.979, tsLoss: 1.123, tsAcc: 0.935
# Epoch: 109, trLoss: 1.072, trAcc: 0.979, tsLoss: 1.121, tsAcc: 0.935
# Epoch: 110, trLoss: 1.071, trAcc: 0.979, tsLoss: 1.122, tsAcc: 0.935
# Epoch: 111, trLoss: 1.071, trAcc: 0.979, tsLoss: 1.120, tsAcc: 0.935
# Epoch: 112, trLoss: 1.073, trAcc: 0.979, tsLoss: 1.125, tsAcc: 0.925
# Epoch: 113, trLoss: 1.072, trAcc: 0.974, tsLoss: 1.126, tsAcc: 0.935
# Epoch: 114, trLoss: 1.072, trAcc: 0.976, tsLoss: 1.128, tsAcc: 0.925
# Epoch: 115, trLoss: 1.072, trAcc: 0.971, tsLoss: 1.142, tsAcc: 0.903
# Epoch: 116, trLoss: 1.077, trAcc: 0.976, tsLoss: 1.132, tsAcc: 0.925
# Epoch: 117, trLoss: 1.074, trAcc: 0.976, tsLoss: 1.124, tsAcc: 0.935
# Epoch: 118, trLoss: 1.073, trAcc: 0.976, tsLoss: 1.125, tsAcc: 0.935
# Epoch: 119, trLoss: 1.073, trAcc: 0.976, tsLoss: 1.116, tsAcc: 0.946
# Epoch: 120, trLoss: 1.073, trAcc: 0.976, tsLoss: 1.119, tsAcc: 0.946
# Epoch: 121, trLoss: 1.072, trAcc: 0.976, tsLoss: 1.113, tsAcc: 0.946
# Epoch: 122, trLoss: 1.072, trAcc: 0.976, tsLoss: 1.112, tsAcc: 0.946
# Epoch: 123, trLoss: 1.074, trAcc: 0.976, tsLoss: 1.112, tsAcc: 0.946
# Epoch: 124, trLoss: 1.072, trAcc: 0.976, tsLoss: 1.117, tsAcc: 0.935
# Epoch: 125, trLoss: 1.072, trAcc: 0.976, tsLoss: 1.112, tsAcc: 0.946
# Epoch: 126, trLoss: 1.071, trAcc: 0.976, tsLoss: 1.116, tsAcc: 0.935
# Epoch: 127, trLoss: 1.071, trAcc: 0.979, tsLoss: 1.123, tsAcc: 0.925
# Training finished

# %%
noiseAmpRatio = 0.0
variableLen = True
pred, target = getPreds(tsLoader, padLen, HARNet, variableLen, noiseAmpRatio=noiseAmpRatio)
cm = confusion_matrix(target,pred,normalize ='true')
for i in range(len(activities)):
    for j in range(len(activities)):
        cm[i, j] = round(cm[i, j], 2)

# print(pred)
# print(target)
print(activities)
activityLabel = ['Lie down', 'Fall', 'Run', 'Sit down', 'Stand up', 'Walk']

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(4,4), dpi =150)
disp.plot(ax=ax)

ax.set_xticklabels(activityLabel, rotation=45, ha='right')
ax.set_yticklabels(activityLabel)
# Out:
# /home/byk004/24-RT_adv_HAR/utilities.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   label = torch.tensor(self.labels[idx], device=self.device).long()
# /home/byk004/24-RT_adv_HAR/utilities.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inputs_padded = pad_sequence([torch.tensor(seq) for seq in inputs],
# ['bed', 'fall', 'run', 'sitdown', 'standup', 'walk']
# [Text(0, 0, 'Lie down'),
#  Text(0, 1, 'Fall'),
#  Text(0, 2, 'Run'),
#  Text(0, 3, 'Sit down'),
#  Text(0, 4, 'Stand up'),
#  Text(0, 5, 'Walk')]

# %%
# noiseAmpRatioList = [1e-2]
noiseAmpRatioList = [1e-5, 1e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 7.5e-2, 0.1, 0.2, 0.5]

nHidden = 200
thres = 60
batchSize = 1
nLayer = 1
bidirectional = True
if bidirectional:
    modelName = "BiLSTM"
else:
    modelName = "LSTM"
# HARNetSavePath = './savedModels/' + dataType + '_' + modelName + '_H_' + str(nHidden) + '_th_' + str(thres) +\
#      '_L_' + str(nLayer) + '.cpkt'
HARNetSavePath = './savedModels/LSTM/survey_BiLSTM_H_' + str(nHidden) + "_dS_" + str(dSampFactor) + ".cpkt"

HARNet = VariableLSTMNet(nClasses=len(activities),\
                input_size=nSubC*nRX,\
                bidirectional=bidirectional,\
                hidden_size=nHidden,\
                num_layers=1,\
                device=device)

HARNet.load_state_dict(torch.load(HARNetSavePath))
HARNet.to(device)
HARNet.eval()
loaderPadLen = padLen
for noiseAmpRatio in noiseAmpRatioList:
    accTest = getAcc(tsLoader,\
                    padLen,\
                    HARNet,\
                    variableLen=True,\
                    noiseAmpRatio=noiseAmpRatio,\
                    noiseType='random')
    # accTest = getAcc(tsLoader, padLen, HARNet, variableLen=True)
    print('NoiseAmpRatio: {0}, Test Acc.: {1:.1f}%'.format(noiseAmpRatio, 100*accTest))
# Out:
# NoiseAmpRatio: 1e-05, Test Acc.: 94.6%
# NoiseAmpRatio: 0.0001, Test Acc.: 94.6%
# NoiseAmpRatio: 0.0005, Test Acc.: 94.6%
# NoiseAmpRatio: 0.001, Test Acc.: 94.6%
# NoiseAmpRatio: 0.002, Test Acc.: 94.6%
# NoiseAmpRatio: 0.005, Test Acc.: 94.6%
# NoiseAmpRatio: 0.01, Test Acc.: 93.5%
# NoiseAmpRatio: 0.02, Test Acc.: 94.6%
# NoiseAmpRatio: 0.05, Test Acc.: 92.5%
# NoiseAmpRatio: 0.075, Test Acc.: 92.5%
# NoiseAmpRatio: 0.1, Test Acc.: 94.6%
# NoiseAmpRatio: 0.2, Test Acc.: 93.5%
# NoiseAmpRatio: 0.5, Test Acc.: 92.5%

# %% [markdown]
# ## Save CSI data and FGM noise

# %%
nData = 0
batchSize = 1
padLen = 9
# dSampFactor = 4

if bidirectional:
    modelName = "BiLSTM"
else:
    modelName = "LSTM"
modelFileName = 'survey_' + modelName + '_H_' + str(nHidden) + '_dS_' + str(dSampFactor)


for actInd, activity in enumerate(activities):
    inputList = []
    FGMList = []
    labelList = []

    print('activity:', activity, end=' ')
    datasetAct = CSIDataset(dataDict[activity], device)

    model = HARNet
    loader = DataLoader(datasetAct, batch_size=batchSize, shuffle=False)
    noiseAmpRatio = .1

    device = model.device
    model.to(device)
    model.train()
    # loss = loss(model())

    dataInput_fileName = "/project/iarpa/wifiHAR/HAR_survey/noWin_dSamp_" +\
        str(dSampFactor)+ "_pad_" + str(padLen) + "_FGM/input_" + modelFileName + "_" + activity
    dataFGM_fileName = "/project/iarpa/wifiHAR/HAR_survey/noWin_dSamp_" +\
        str(dSampFactor)+ "_pad_" + str(padLen) + "_FGM/FGM_" + modelFileName + "_" + activity
    
    for batch in loader:
        batchInput = batch['input']
        batchInput = batchInput * torch.numel(batchInput) /\
            (LA.norm(batchInput) * nSubC * nRX)

        batchInputWoPad = batchInput[:, padLen:, :]      

        inputFlatten = batchInputWoPad.view(batchInputWoPad.shape[0], -1)
        noiseAmp = LA.norm(inputFlatten, dim=1) * noiseAmpRatio
        batchLabel = batch['label']
        
        batchInputWoPad.requires_grad = True
        model.zero_grad()
        loss = nn.CrossEntropyLoss()
        lossOutput = loss(model(batchInputWoPad), batchLabel)
        lossOutput.backward()
        noise = (batchInputWoPad.grad.data).view(batchInputWoPad.shape[0], -1)
        noiseNorm = torch.mul(torch.div(noise, LA.norm(noise, dim=1).unsqueeze(1)),\
                              noiseAmp.unsqueeze(1))

        # print(LA.norm(batchInput).item(), LA.norm(noiseNorm).item())
        inputList.append(torch.squeeze(batchInput).cpu().detach())
        batchNoiseNorm = noiseNorm.view(batchInputWoPad.shape)
        FGMList.append(torch.squeeze(batchNoiseNorm).cpu().detach())
        labelList.append([actInd])

    np.save(dataInput_fileName, np.array(inputList, dtype=object), allow_pickle=True)
    np.save(dataFGM_fileName, np.array(FGMList, dtype=object), allow_pickle=True)
    print('nDataAct:', len(inputList))


print('nData:', nData)
# Out:
# activity: bed
# /tmp/ipykernel_1879966/3440706271.py:61: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   np.save(dataInput_fileName, np.array(inputList, dtype=object), allow_pickle=True)
# /tmp/ipykernel_1879966/3440706271.py:62: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   np.save(dataFGM_fileName, np.array(FGMList, dtype=object), allow_pickle=True)
# nDataAct: 79
# activity: fall nDataAct: 79
# activity: run nDataAct: 80
# activity: sitdown nDataAct: 80
# activity: standup nDataAct: 79
# activity: walk nDataAct: 80
# nData: 0

# %% [markdown]
# ## Load saved pre-trained LSTM model and evaluate (noise may be added)

# %%
noiseAmpRatioList = [1e-2]
# noiseAmpRatioList = [1e-5, 1e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 7.5e-2, 0.1, 0.2, 0.5]

nHidden = 200
thres = 60
batchSize = 200
nLayer = 1
bidirectional = True
if bidirectional:
    modelName = "BLSTM"
else:
    modelName = "LSTM"
HARNetSavePath = './savedModels/selected/survey_BiLSTM_H_200.cpkt'

HARNet = VariableLSTMNet(nClasses=len(activities),\
                input_size=nSubC*nRX,\
                bidirectional=bidirectional,\
                hidden_size=nHidden,\
                num_layers=1,\
                device=device)
HARNet.load_state_dict(torch.load(HARNetSavePath))
HARNet.to(device)

loaderPadLen = padLen
for noiseAmpRatio in noiseAmpRatioList:
    correct = 0.0
    # accTest = getAcc(trLoader, 9, HARNet, variableLen=True,\
    #                  noiseAmpRatio=noiseAmpRatio, noiseType='FGM')
    print(len(inputList), len(FGMList), len(labelList))
    # for trInput, trFGM, trLabel in zip(inputList, FGMList, labelList):
    #     print(trInput.shape)
    pred_l, label_l = getPredsGAIL(inputList, FGMList, torch.Tensor(labelList), HARNet,\
                        noiseAmpRatio=noiseAmpRatio, padLen=padLen)    
    for pred, label in zip(pred_l, label_l):
        print(pred, label.item())
        nData += 1
        correct += (pred == label)

    print('NoiseAmpRatio:', noiseAmpRatio, ' Test accuracy:', correct/len(inputList))
# Out:
# 477 477 477
# 3 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 3 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 2 tensor([0.])
# 5 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 1 tensor([0.])
# 2 tensor([0.])
# 3 tensor([0.])
# 2 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 2 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 4 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 5 tensor([0.])
# 0 tensor([0.])
# 2 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 2 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 2 tensor([0.])
# 2 tensor([0.])
# 0 tensor([0.])
# 0 tensor([0.])
# 3 tensor([0.])
# 0 tensor([0.])
# 2 tensor([0.])
# 1 tensor([1.])
# 2 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 2 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 2 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 3 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 4 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 2 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 4 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 1 tensor([1.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 3 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 5 tensor([2.])
# 2 tensor([2.])
# 2 tensor([2.])
# 0 tensor([2.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 4 tensor([3.])
# 3 tensor([3.])
# 0 tensor([3.])
# 0 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 1 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 4 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 4 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 0 tensor([3.])
# 3 tensor([3.])
# 0 tensor([3.])
# 0 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 3 tensor([3.])
# 4 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 1 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 1 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 0 tensor([4.])
# 4 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 3 tensor([4.])
# 4 tensor([4.])
# 1 tensor([4.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# 2 tensor([5.])
# 5 tensor([5.])
# 2 tensor([5.])
# NoiseAmpRatio: 0.01  Test accuracy: tensor([0.7044])

# %%
nDataTs = 0
for tsBatch in tsLoader:
    nDataTs += tsBatch['obs'].shape[0]

lineBreakCount = 0
for noiseAmpRatio in noiseAmpRatioList:
    correct = 0.
    for trAgentBatch in tsLoader:
        trObsBatchwoPad = trAgentBatch['obs'][:, padLen:, :]
        pred_l,label_l = getPredsGAIL(trObsBatchwoPad, trAgentBatch['FGM'], trAgentBatch['label'],\
                                        HARNet, noiseAmpRatio)
        for pred, label in zip(pred_l, label_l):
            correct += (pred == label)
    print('[{0}, {1:.3f}]'.format(noiseAmpRatio, correct/nDataTs), end=' ')

    lineBreakCount += 1
    if lineBreakCount == 4:
        print('')
        lineBreakCount = 0

# %%
nData = 0
batchSize = 1
for actInd, activity in enumerate(activities):
    datasetAct = CSIDataset(dataDict[activity], device)
    loader = DataLoader(datasetAct, batch_size=batchSize, shuffle=False)

    for batch in loader:
        nData += batch['input'].shape[0]
print('nData:', nData, end=' ')


correct = 0.
for actInd, activity in enumerate(activities):
    datasetAct = CSIDataset(dataDict[activity], device)

    model = HARNet
    loader = DataLoader(datasetAct, batch_size=batchSize, shuffle=False)
    noiseAmpRatio = .1

    device = model.device
    model.to(device)
    model.train()

    dataInputPaddedAct = torch.empty((0, ((winLen//2+padLen) * nSubC*nRX))).to(device)
    dataNoiseAct = torch.empty((0, ((winLen//2) * nSubC*nRX))).to(device)
    dataInput_fileName = "/project/iarpa/wifiHAR/HAR_survey/noWin_FGM_pad_" +\
        str(padLen) + "/input_" + dataType + "_LSTM_H_200_th_" + str(thres) + "_L_1_" + activity + ".npy"
    dataNoise_fileName = "/project/iarpa/wifiHAR/HAR_survey/noWin_FGM_pad_" +\
        str(padLen) + "/noise_" + dataType + "_LSTM_H_200_th_" + str(thres) + "_L_1_" + activity + ".npy"

    for batch in loader:
        model.zero_grad()
        model.train()
        inputFlatten = batch['input'].view(batch['input'].shape[0], -1)
        noiseAmp = LA.norm(inputFlatten, dim=1) * (winLen//2) / (winLen//2 + padLen) * noiseAmpRatio

        batcchInputWoPad = batch['input'][:, padLen:, :]
        batcchInputWoPad.requires_grad = True
        loss = nn.CrossEntropyLoss()
        loss = loss(model(batcchInputWoPad), batch['label'])
        loss.backward()
        batchNoise = (batcchInputWoPad.grad.data).view(batcchInputWoPad.shape[0], -1)
        batchNoise = torch.mul(torch.div(batchNoise, LA.norm(batchNoise, dim=1).unsqueeze(1)),\
                            noiseAmp.unsqueeze(1))
        batchInput = batch['input'].view(batch['input'].shape[0], -1)

        batchLabel =\
            actInd * torch.ones_like(torch.empty(batchInput.shape[0], device=device), dtype=int)

        pred_l,label_l = getPredsGAIL(batcchInputWoPad, batchNoise, batchLabel,\
                                HARNet, noiseAmpRatio)
        for pred, label in zip(pred_l, label_l):
            correct += (pred == label)


        # print(batchInput.shape, batchNoise.shape, batcchInputWoPad.shape)
        dataInputPaddedAct = torch.cat((dataInputPaddedAct, batchInput), 0)
        dataNoiseAct = torch.cat((dataNoiseAct, batchNoise), 0)
        # print(dataInputPaddedAct.shape, dataNoiseAct.shape)

    dataInputPaddedActNp = dataInputPaddedAct.cpu().detach().numpy()
    dataNoiseActNp = dataNoiseAct.cpu().detach().numpy()
    print('activity:', activity, dataInputPaddedActNp.shape, dataNoiseActNp.shape)
    with open(dataInput_fileName, 'wb') as f:
        np.save(f, dataInputPaddedActNp)
    with open(dataNoise_fileName, 'wb') as f:
        np.save(f, dataNoiseActNp)

print('[{0}, {1:.3f}]'.format(noiseAmpRatio, correct/nData))

# %% [markdown]
# ## save non-windowed data (but dowmsanpled)

# %%
padLen = 9
print(dataPath)
noWindDataPath = dataPath + "noWin_pad" + str(padLen) + "/"
for activity in activities:
    if dataType == "survey":
        fileNameList = glob(dataPath + "/input_" + activity + "*.csv")
        outputXXFileName = noWindDataPath + "xx_" + activity

        print(activity, len(fileNameList))

        # xx = np.empty([0, (winLen//dSampFactor + padSize), nSubC*nRX], float)
    dataList = []

    for fileIndex, fileName in enumerate(fileNameList):
        data = np.array([[float(elm) for elm in v] for v in csv.reader(open(fileName, 'r'))])
        annotFileName = fileName.replace('input', 'annotation')
        annot = np.array([[str(elm) for elm in v] for v in csv.reader(open(annotFileName, 'r'))])
        annotDownSamp = annot[::dSampFactor]

        indActs = np.where(annot[:, 0] == activity)[0]
        indPad = np.arange(indActs[0]-padLen*dSampFactor, indActs[0], dSampFactor)
        indActswithPad = np.concatenate((indPad, indActs))
        # print(indActswithPad.shape)
        # print(indPad, indActs[:5], indActswithPad[:15])
        
        dataActs = data[indActswithPad, 1:1+nSubC*nRX]
        dataList.append(dataActs)

    np.save(outputXXFileName, np.array(dataList, dtype=object), allow_pickle=True)
    # with open(outputXXFileName, "w+") as f:
    #     pickle.dump(dataList, f)
